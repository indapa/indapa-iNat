# %%
from pyinaturalist import *

import pyinaturalist as pynat

# %%
observations = pynat.get_observations(
    user_id='indapa')

pynat.pprint(observations)
# Out:
#
#   ID          Taxon ID   Taxon                             Observed on    User     Location
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   279586251   55505      Allium triquetrum                 May 08, 2025   indapa   Dove Loop, San Francisco, CA,
#                          (Three-Cornered Garlic)                                   US
#   279586145   538900     Subgenus Pyrobombus               May 08, 2025   indapa   Batteries to Bluffs Trail, San
#                                                                                    Francisco, CA, US
#   279585991   53405      Heteromeles arbutifolia (Toyon)   May 08, 2025   indapa   Batteries to Bluffs Trail, San
#                                                                                    Francisco, CA, US
#   279585898   50878      Erigeron glaucus (Seaside         May 08, 2025   indapa   Dove Loop, San Francisco, CA,
# ...

# %%
for obs in observations['results']:
    pynat.pprint(obs)
# Out:
#
#   ID          Taxon ID   Taxon                            Observed on    User     Location
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   279586251   55505      Allium triquetrum                May 08, 2025   indapa   Dove Loop, San Francisco, CA,
#                          (Three-Cornered Garlic)                                  US
#
#   ID          Taxon ID   Taxon                 Observed on    User     Location
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   279586145   538900     Subgenus Pyrobombus   May 08, 2025   indapa   Batteries to Bluffs Trail, San Francisco,
#                                                                        CA, US
#
#   ID          Taxon ID   Taxon                             Observed on    User     Location
# ...

# %%
counts = pynat.get_observation_species_counts(user_id='indapa', quality_grade='research')
pynat.pprint(counts)
# Out:
#
#   ID        Rank      Scientific name                 Common name                     Count
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   52108     species   🌼 Baccharis sarothroides       Desert Broom                    4
#   54999     species   🌱 Eriogonum fasciculatum       California Buckwheat            4
#   17013     species   🐦 Sayornis nigricans           Black Phoebe                    3
#   18209     species   🐦 Melanerpes formicivorus      Acorn Woodpecker                3
#   49918     species   🌱 Sisyrinchium bellum          western blue-eyed grass         3
#   64134     species   🌱 Salvia apiana                white sage                      3
#   64141     species   🌻 Encelia californica          California brittlebush          3
#   68205     species   🌱 Larrea tridentata            Creosote Bush                   3
#   8010      species   🐦 Corvus corax                 Common Raven                    2
# ...
